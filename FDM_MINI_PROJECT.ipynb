# %% [markdown]
# <a href="https://colab.research.google.com/github/shashithenuwara/FDM-MINI_project/blob/main/FDM_MINI_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("Sleep_Data_Sampled.csv")

# %%
df.head()
# Out:
#    Person ID Gender   Age         Occupation  Sleep Duration  \
# 0        1.0   Male  35.0             Doctor            6.65
# 1        2.0   Male  42.0            Teacher            6.90
# 2        3.0   Male  34.0  Software Engineer            6.95
# 3        4.0   Male  32.0             Doctor            6.90
# 4        5.0   Male  37.0             Lawyer            6.85
#
#    Quality of Sleep  Physical Activity Level  Stress Level   BMI Category  \
# 0               7.0                     50.0           7.0  Normal Weight
# 1               8.0                     52.0           4.0         Normal
# 2               7.0                     66.0           6.0     Overweight
# 3               6.0                     52.0           7.0         Normal
# 4               7.0                     60.0           6.0         Normal
#
#   Blood Pressure  Heart Rate  Daily Steps  Fatigue Score Sleep Disorder
# 0         120/80        71.0         7100           7.52        Healthy
# 1         135/90        66.0         7000           7.54        Healthy
# 2         126/83        74.0         6100           9.50        Healthy
# 3         120/80        71.0         6500           7.54        Healthy
# 4         125/80        71.0         6500           8.76        Healthy
